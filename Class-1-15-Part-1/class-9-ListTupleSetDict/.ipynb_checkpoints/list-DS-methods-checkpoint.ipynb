# %%
#create
l1=[]  #empty list
l2=[10,20,10,30.5,"Rahul",True]
eids=[101,102,103,104]
#read
print(l1)
print(l2)
print(eids)

#how to read list elements
# Out:
# []
# [10, 20, 10, 30.5, 'Rahul', True]
# [101, 102, 103, 104]

# %%
eids=[101,102,103,104]
#how to read list elements
print(eids[0])
print(eids[1])
print(eids[2])
print(eids[3])
# Out:
# 101
# 102
# 103
# 104

# %%
eids=[101,102,103,104]
#index 0   1   2   3
#how to read list elements
print(eids[0])
print(eids[1])
print(eids[2])
print(eids[3])
print(eids[8])    #IndexError:
# Out:
# 101
# 102
# 103
# 104
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 8
#       6 print(eids[2])
#       7 print(eids[3])
# ----> 8 print(eids[8])    #IndexError:
#
# IndexError: list index out of range

# %%
eids=[101,102,103,104]
#index 0   1   2   3
eids[0] = 100
print(eids)
# Out:
# [100, 102, 103, 104]

# %%
del eids[0]
print(eids)
# Out:
# [102, 103, 104]

# %%
eids=[101,102,101,101,102,103]
uids=eids.copy()
print(uids)
# Out:
# [101, 102, 101, 101, 102, 103]

# %%
eids=[101,102,101,101,102,103]
print(eids.count(101))
# Out:
# 3

# %%
eids=[101,102,101,101,102,103]
#index 0  1     2   3  4    5 
print(eids.index(102))
# Out:
# 1

# %%
enames=["Rahul","Sonia","Priyanka"]
enames.append("Modi")
print(enames)
# Out:
# ['Rahul', 'Sonia', 'Priyanka', 'Modi']

# %%
enames=["Rahul","Sonia","Priyanka"]
#index    0        1       2
enames.insert(1,"Rajiv")
print(enames)
# Out:
# ['Rahul', 'Rajiv', 'Sonia', 'Priyanka']

# %%
enames=["Rahul","Sonia","Priyanka"]
unames=["Modi","Amith","Rajni"]
enames.extend(unames)
print(enames)
# Out:
# ['Rahul', 'Sonia', 'Priyanka', 'Modi', 'Amith', 'Rajni']

# %%
enames=['Rahul', 'Sonia', 'Priyanka', 'Modi', 'Amith', 'Rajni']
enames.sort()
print(enames)
# Out:
# ['Amith', 'Modi', 'Priyanka', 'Rahul', 'Rajni', 'Sonia']

# %%
enames=['Rahul', 'Sonia', 'Priyanka', 'Modi', 'Amith', 'Rajni']
enames.sort(reverse=True)  #Descending 
print(enames)
# Out:
# ['Sonia', 'Rajni', 'Rahul', 'Priyanka', 'Modi', 'Amith']

# %%
numbers=[11,31,7,8,232,1055]
numbers.sort() #Asedning Order - Natural Sorting order
print(numbers) #[7,8,11,31,232,1055]
# Out:
# [7, 8, 11, 31, 232, 1055]

# %%
numbers=[11,31,7,8,232,1055]
numbers.reverse()
print(numbers)
# Out:
# [1055, 232, 8, 7, 31, 11]

# %%
enames=['Rahul', 'Sonia', 'Priyanka', 'Modi', 'Amith', 'Rajni']
enames.pop()
print(enames)
# Out:
# ['Rahul', 'Sonia', 'Priyanka', 'Modi', 'Amith']

# %%
enames=['Rahul', 'Sonia', 'Priyanka', 'Modi', 'Amith', 'Rajni']
enames.remove("Priyanka")
print(enames)
# Out:
# ['Rahul', 'Sonia', 'Modi', 'Amith', 'Rajni']

# %%
enames=['Rahul', 'Sonia', 'Priyanka', 'Modi', 'Amith', 'Rajni']
enames.remove("Vijay")    #ValueError
print(enames)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 enames=['Rahul', 'Sonia', 'Priyanka', 'Modi', 'Amith', 'Rajni']
# ----> 2 enames.remove("Vijay")    #ValueError
#       3 print(enames)
#
# ValueError: list.remove(x): x not in list

# %%
enames=['Rahul', 'Sonia', 'Priyanka', 'Modi', 'Amith', 'Rajni']
enames.clear()   #remove all elements from list
print(enames)  #[]
# Out:
# []

# %%
enames=['Rahul', 'Sonia', 'Priyanka', 'Modi', 'Amith', 'Rajni']
del enames
print(enames)  #NameError
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 enames=['Rahul', 'Sonia', 'Priyanka', 'Modi', 'Amith', 'Rajni']
#       2 del enames
# ----> 3 print(enames)  #NameError
#
# NameError: name 'enames' is not defined
