# %%
t1=()
t2=100,200
print(type(t1))
print(type(t2))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
enames=("Rahul","Sonia","Priyanka")
print(enames)
# Out:
# ('Rahul', 'Sonia', 'Priyanka')

# %%
enames=("Rahul","Sonia","Priyanka")
unames=enames.copy()
print(unames)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 enames=("Rahul","Sonia","Priyanka")
# ----> 2 unames=enames.copy()
#       3 print(unames)
#
# AttributeError: 'tuple' object has no attribute 'copy'

# %%
enames=("Rahul","Sonia","Priyanka","Sonia")
#index     0       1       2             3
print(enames.count("Sonia"))  #2
print(enames.index("Sonia"))  #1
# Out:
# 2
# 1

# %%
enames=("Rahul","Sonia","Priyanka","Sonia")
enames.append("Modi")   #AttributeError
enames.eat("Amith")     #AttibuteError
