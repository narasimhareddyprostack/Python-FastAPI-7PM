# %%
l1=[10,20,30,"Rahul",10,20]
s1={10,20,30,"Rahul",10,20}
print(l1)        #[10,20,30,"Rahul",10,20]    - Order maintantied
print(s1)        #{10,20,30,"Rahul"}          - order not maintained
# Out:
# [10, 20, 30, 'Rahul', 10, 20]
# {10, 20, 'Rahul', 30}

# %%
l1=[10,20,30,"Rahul",10,20]
s1={10,20,30,"Rahul",10,20}
print(l1)        #[10,20,30,"Rahul",10,20]    - Order maintantied
print(s1)        #{10, 20, 'Rahul', 30}         - order not maintained
# Out:
# [10, 20, 30, 'Rahul', 10, 20]
# {10, 20, 'Rahul', 30}
