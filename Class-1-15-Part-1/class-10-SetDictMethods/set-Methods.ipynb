# %%
s1={}
print(s1)         #{}
print(type(s1)) #<class,dict>
# Out:
# {}
# <class 'dict'>

# %%
#How to create empty set object?
s2=set()     
print(len(s2))
# Out:
# 0

# %%
s2=set()     

s2.add(10)
s2.add(20)
s2.add(30)
s2.add("Rahul")
print(s2)            #set - order not maintained.
# Out:
# {10, 20, 'Rahul', 30}

# %%
s1={10,20,30}
s2={30,40,50}
s1.update(s2)  
print(s1)  #{10,20,30,40,50}
# Out:
# {50, 20, 40, 10, 30}

# %%
s1={10,20,30}
s1.update(40)
print(s1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 s1={10,20,30}
# ----> 2 s1.update(40)
#       3 print(s1)
#
# TypeError: 'int' object is not iterable

# %%
enames={"RG","SG","PG","Modi"}
enames.pop()        #remove arbitary/random element
print(enames)
# Out:
# {'RG', 'Modi', 'SG'}

# %%
enames={"RG","SG","PG","Modi"}
enames.remove('RG')  #remove specified elment from set
print(enames)
# Out:
# {'PG', 'Modi', 'SG'}

# %%
enames={"RG","SG","PG","Modi"}
enames.discard('RG')  #remove specified elment from set
print(enames)
# Out:
# {'PG', 'Modi', 'SG'}

# %%
enames={"RG","SG","PG","Modi"}
enames.remove('Rajni')       #Error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 2
#       1 enames={"RG","SG","PG","Modi"}
# ----> 2 enames.remove('Rajni')       #Error
#
# KeyError: 'Rajni'

# %%
enames={"RG","SG","PG","Modi"}
enames.discard('Rajni')       #No Error
